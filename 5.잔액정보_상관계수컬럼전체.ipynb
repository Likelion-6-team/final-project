# %%
import pandas as pd
import numpy as np
from dython.nominal import associations
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_parquet('1.회원정보_train.parquet')
df1 = pd.read_parquet('5.잔액정보_train.parquet')

# %%
df1 = df1.drop('연체일자_B0M',axis=1)

# %%
# LabelEncoder 하기

le = LabelEncoder()

df['Segment'] = le.fit_transform(df['Segment'].astype(str))
df1['ID'] = le.fit_transform(df1['ID'])

# %%
# 피어슨 상관계수 구하기

segment = df['Segment']

correlations = df1.corrwith(segment, method = 'pearson')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
significant_corr = correlations[correlations.abs() >= 0.1]
print(significant_corr)
# Out:
# 잔액_일시불_B0M       -0.417354
# 잔액_할부_B0M        -0.264292
# 잔액_현금서비스_B0M     -0.265011
# 월중평잔_일시불_B0M     -0.444621
# 월중평잔_할부_B0M      -0.234879
# 월중평잔_CA_B0M      -0.264076
# 잔액_현금서비스_B1M     -0.264744
# 잔액_현금서비스_B2M     -0.265487
# 잔액_할부_B1M        -0.228537
# 잔액_할부_B2M        -0.228411
# 잔액_일시불_B1M       -0.374244
# 잔액_일시불_B2M       -0.373494
# 잔액_할부_유이자_B0M    -0.146062
# 잔액_할부_무이자_B0M    -0.249776
# 월중평잔             -0.287289
# 월중평잔_일시불         -0.441527
# 월중평잔_RV일시불       -0.120210
# 월중평잔_할부          -0.232085
# 월중평잔_CA          -0.266320
# 평잔_3M            -0.268472
# 평잔_일시불_3M        -0.434514
# 평잔_일시불_해외_3M     -0.292834
# 평잔_RV일시불_3M      -0.117160
# 평잔_RV일시불_해외_3M   -0.117664
# 평잔_할부_3M         -0.233328
# 평잔_CA_3M         -0.267652
# 평잔_6M            -0.281497
# 평잔_일시불_6M        -0.447967
# 평잔_일시불_해외_6M     -0.312756
# 평잔_RV일시불_6M      -0.120489
# 평잔_RV일시불_해외_6M   -0.121709
# 평잔_할부_6M         -0.250312
# 평잔_CA_6M         -0.273914
# dtype: float64

# %%
correlations = df1.corrwith(segment, method='pearson')
corr_df = correlations.to_frame()
corr_df
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
#                               0
# 기준년월               8.217349e-19
# ID                 1.218077e-03
# 잔액_일시불_B0M        -4.173537e-01
# 잔액_할부_B0M         -2.642918e-01
# 잔액_현금서비스_B0M      -2.650108e-01
# 잔액_리볼빙일시불이월_B0M   -6.967906e-02
# 잔액_리볼빙CA이월_B0M    -1.597595e-03
# 잔액_카드론_B0M        -4.538443e-02
# 월중평잔_일시불_B0M      -4.446213e-01
# 월중평잔_할부_B0M       -2.348788e-01
# 월중평잔_CA_B0M       -2.640757e-01
# 카드론잔액_최종경과월                 NaN
# 연체잔액_B0M          -4.796210e-03
# 연체잔액_일시불_B0M      -6.421011e-03
# 연체잔액_할부_B0M       -6.645312e-03
# 연체잔액_현금서비스_B0M    -2.996266e-03
# 연체잔액_카드론_B0M      -2.469589e-04
# 연체잔액_대환론_B0M       7.311299e-04
# 잔액_현금서비스_B1M      -2.647443e-01
# 잔액_현금서비스_B2M      -2.654866e-01
# 잔액_카드론_B1M        -4.370649e-02
# 잔액_카드론_B2M        -4.523792e-02
# 잔액_카드론_B3M        -4.686582e-02
# 잔액_카드론_B4M        -4.890306e-02
# 잔액_카드론_B5M        -5.139284e-02
# 잔액_할부_B1M         -2.285373e-01
# 잔액_할부_B2M         -2.284110e-01
# 잔액_일시불_B1M        -3.742437e-01
# 잔액_일시불_B2M        -3.734945e-01
# 연체일수_B1M          -2.825491e-02
# 연체일수_B2M          -3.523933e-02
# 연체원금_B1M          -1.143670e-02
# 연체원금_B2M          -1.171650e-02
# 연체일수_최근            4.194225e-02
# 연체원금_최근           -1.002700e-02
# 최종연체회차            -4.351491e-02
# 매각잔액_B1M           2.984966e-04
# 최종연체개월수_R15M                NaN
# RV_평균잔액_R12M      -6.160224e-02
# RV_최대잔액_R12M      -7.593411e-02
# RV_평균잔액_R6M       -6.383759e-02
# RV_최대잔액_R6M       -7.283095e-02
# RV_평균잔액_R3M       -6.666886e-02
# RV_최대잔액_R3M       -7.141417e-02
# RV잔액이월횟수_R6M                NaN
# RV잔액이월횟수_R3M                NaN
# 잔액_할부_유이자_B0M     -1.460622e-01
# 잔액_할부_무이자_B0M     -2.497760e-01
# 잔액_할부_해외_B0M      -8.217860e-03
# 연체잔액_일시불_해외_B0M             NaN
# 연체잔액_RV일시불_B0M    -5.534963e-04
# 연체잔액_RV일시불_해외_B0M           NaN
# 연체잔액_할부_해외_B0M              NaN
# 연체잔액_CA_B0M       -7.851869e-03
# 연체잔액_CA_해외_B0M              NaN
# 월중평잔              -2.872888e-01
# 월중평잔_일시불          -4.415268e-01
# 월중평잔_RV일시불        -1.202100e-01
# 월중평잔_할부           -2.320852e-01
# 월중평잔_CA           -2.663203e-01
# 월중평잔_카드론          -4.212317e-02
# 평잔_3M             -2.684721e-01
# 평잔_일시불_3M         -4.345136e-01
# 평잔_일시불_해외_3M      -2.928340e-01
# 평잔_RV일시불_3M       -1.171595e-01
# 평잔_RV일시불_해외_3M    -1.176643e-01
# 평잔_할부_3M          -2.333278e-01
# 평잔_할부_해외_3M       -2.039534e-02
# 평잔_CA_3M          -2.676521e-01
# 평잔_CA_해외_3M       -5.996236e-03
# 평잔_카드론_3M         -3.764922e-02
# 평잔_6M             -2.814974e-01
# 평잔_일시불_6M         -4.479670e-01
# 평잔_일시불_해외_6M      -3.127556e-01
# 평잔_RV일시불_6M       -1.204894e-01
# 평잔_RV일시불_해외_6M    -1.217086e-01
# 평잔_할부_6M          -2.503124e-01
# 평잔_할부_해외_6M       -2.745745e-02
# 평잔_CA_6M          -2.739135e-01
# 평잔_CA_해외_6M       -1.169262e-02
# 평잔_카드론_6M         -4.205892e-02
