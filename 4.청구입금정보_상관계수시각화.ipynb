# %%
import pandas as pd
import numpy as np
from dython.nominal import associations
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
# 'Malgun Gothic' 폰트를 기본으로 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
a1 = pd.read_csv('4.청구입금정보_상관계수.csv')
a1.head()
# Out:
#              컬럼명          상관계수
# 0           기준년월  8.217349e-19
# 1             ID  1.218077e-03
# 2          대표결제일  3.646445e-03
# 3       대표결제방법코드           NaN
# 4  대표청구지고객주소구분코드  6.818304e-02

# %%
a1['상관계수'] = abs(a1['상관계수'])
a1
# Out:
#                  컬럼명          상관계수
# 0               기준년월  8.217349e-19
# 1                 ID  1.218077e-03
# 2              대표결제일  3.646445e-03
# 3           대표결제방법코드           NaN
# 4      대표청구지고객주소구분코드  6.818304e-02
# 5       대표청구서수령지구분코드  1.805543e-02
# 6            청구서수령방법  2.596360e-02
# 7         청구서발송여부_B0  2.095341e-01
# 8        청구서발송여부_R3M  1.870362e-01
# 9        청구서발송여부_R6M  1.536969e-01
# 10           청구금액_B0  5.779884e-01
# 11          청구금액_R3M  5.906781e-01
# 12          청구금액_R6M  5.979035e-01
# 13   포인트_마일리지_건별_B0M  2.149170e-01
# 14   포인트_마일리지_건별_R3M  2.166431e-01
# 15    포인트_포인트_건별_B0M  1.445468e-01
# 16    포인트_포인트_건별_R3M  1.467265e-01
# 17  포인트_마일리지_월적립_B0M  1.755938e-01
# 18  포인트_마일리지_월적립_R3M  1.806338e-01
# 19   포인트_포인트_월적립_B0M  1.156051e-01
# 20   포인트_포인트_월적립_R3M  1.256698e-01
# 21    포인트_적립포인트_R12M  1.753621e-01
# 22     포인트_적립포인트_R3M  1.732861e-01
# 23    포인트_이용포인트_R12M  1.432407e-01
# 24     포인트_이용포인트_R3M  1.701519e-01
# 25     포인트_잔여포인트_B0M  2.584055e-03
# ...

# %%
# top30 = a1.sort_values(by='상관계수', ascending=False).head(30)

# %%
a1=a1.sort_values(by='상관계수', ascending = False)

# %%
sns.barplot(data=a1, x='상관계수', hue='컬럼명', palette='coolwarm')
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=8)
plt.legend().remove()
plt.show()
