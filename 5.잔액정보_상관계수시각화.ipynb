# %%
import pandas as pd
import numpy as np
from dython.nominal import associations
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# 'Malgun Gothic' 폰트를 기본으로 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
a1 = pd.read_csv('5.잔액정보_상관계수.csv')
a1.head()
# Out:
#             컬럼명          상관계수
# 0          기준년월  8.217349e-19
# 1            ID  1.218077e-03
# 2    잔액_일시불_B0M -4.173537e-01
# 3     잔액_할부_B0M -2.642918e-01
# 4  잔액_현금서비스_B0M -2.650108e-01

# %%
a1['상관계수'] = abs(a1['상관계수'])
a1
# Out:
#              컬럼명          상관계수
# 0           기준년월  8.217349e-19
# 1             ID  1.218077e-03
# 2     잔액_일시불_B0M  4.173537e-01
# 3      잔액_할부_B0M  2.642918e-01
# 4   잔액_현금서비스_B0M  2.650108e-01
# ..           ...           ...
# 76      평잔_할부_6M  2.503124e-01
# 77   평잔_할부_해외_6M  2.745745e-02
# 78      평잔_CA_6M  2.739135e-01
# 79   평잔_CA_해외_6M  1.169262e-02
# 80     평잔_카드론_6M  4.205892e-02
#
# [81 rows x 2 columns]

# %%
# top20 = a1.sort_values(by='상관계수', ascending=False).head(20)

# %%
a1=a1.sort_values(by='상관계수',ascending=False)

# %%
sns.barplot(data=a1, x='상관계수', hue='컬럼명', palette='coolwarm')
plt.legend().remove()
# plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=8)
plt.show()
